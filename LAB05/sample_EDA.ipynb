# %% [markdown]
# <h1>I. TỔNG QUAN (Phần chung cho cả 3 phần bài tập)</h1>

# %% [markdown]
# <h2>1. Tóm tắt bài toán</h2>

# %% [markdown]
# <!-- Mô tả sơ vấn đề bài toán -->

# %% [markdown]
# <h2>2. Mô tả các biến</h2>

# %% [markdown]
# <!-- Giải thích sơ các biến -->

# %% [markdown]
# <h1>II. BÀI TẬP</h1>

# %% [markdown]
# <h2>1. Thống kê mô tả</h2>

# %% [markdown]
# <h3>1.1 Tính mean, median, mode, variance, standard deviation, range, percentile, quartile, interquartile range
# (IQR) sử dụng thư viện numpy và stats trên tập dữ liệu</h3>

# %%
# Thực hiện code ở đây (tương tự trong file pdf)

# %% [markdown]
# <!-- Giải thích các code -->

# %% [markdown]
# <h3>1.2 Loại bỏ dữ liệu trùng lặp, thay thế dữ liệu và thay đổi định dạng của dữ liệu và xử lý dữ liệu thiếu</h3>

# %%
# Thực hiện code ở đây (tương tự trong file pdf)

# %% [markdown]
# <!-- Giải thích các code -->

# %% [markdown]
# <h2>2. Xử lý và trực quan hóa dữ liệu</h2>

# %% [markdown]
# <h3>2.1 Chuẩn bị dữ liệu cho trực quan hóa dữ liệu, trực quan hóa dữ liệu với thư viện Matplotlib và Seaborn</h3>

# %%
# Thực hiện code ở đây (giống trong file pdf)

# %% [markdown]
# <!-- Giải thích code -->

# %% [markdown]
# <h2>3. Phân tích dữ liệu đơn biến và hai biến </h2>

# %% [markdown]
# <h3>3.1 Phân tích dữ liệu đơn biến</h3>

# %%
# Thực hiện code ở đây (giống trong file pdf)

# %% [markdown]
# <!-- Giải thích code -->

# %% [markdown]
# <h3>3.2 Phân tích dữ liệu đa biến</h3>

# %%
# Thực hiện code ở đây (giống trong file pdf)

# %% [markdown]
# <!-- Giải thích code -->

# %% [markdown]
# <h3>3.3 Sử dụng pandas profiling</h3>

# %%
# Thực hiện code ở đây (giống trong file pdf)

# %% [markdown]
# <!-- Giải thích code -->

# %% [markdown]
# <h3>3.4 Sử dụng dtale</h3>

# %%
# Thực hiện code ở đây (giống trong file pdf)

# %% [markdown]
# <!-- Giải thích code -->
